# %%
try:
    # %pip install --user "oracledb" --no-warn-script-location
except Exception as e:
    print("\x1b[31m\u2717 Unexpected error! Please contact course staff\n" +
         "Please include the entire text above and below in your message.")
    raise
# Out:
# Collecting oracledb
#   Downloading oracledb-3.4.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (7.7 kB)
# Requirement already satisfied: cryptography>=3.2.1 in /opt/anaconda3/envs/cpsc330/lib/python3.12/site-packages (from oracledb) (46.0.3)
# Requirement already satisfied: typing_extensions>=4.14.0 in /opt/anaconda3/envs/cpsc330/lib/python3.12/site-packages (from oracledb) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/cpsc330/lib/python3.12/site-packages (from cryptography>=3.2.1->oracledb) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/cpsc330/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.2.1->oracledb) (2.22)
# Downloading oracledb-3.4.2-cp312-cp312-macosx_10_13_universal2.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 6.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: oracledb
# Successfully installed oracledb-3.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import oracledb
import csv

# %%
dsn = oracledb.makedsn("localhost", 1522, service_name="stu")
connection = oracledb.connect(user="ora_lding04", password="a88101027", dsn=dsn)

# %%
cur = connection.cursor()

# %%
cur.execute("DROP TABLE imdb_title_basics")

# %%
cur.execute("""
    CREATE TABLE imdb_title_basics (sdsdsdsdsdsdsdissnjdfiewnfiqwenfinfknf
        tconst VARCHAR2(20) NOT NULL PRIMARY KEY,
        titleType VARCHAR2(50),
        primaryTitle VARCHAR2(500),
        originalTitle VARCHAR2(500),
        isAdult NUMBER(1),
        startYear NUMBER(4),
        endYear NUMBER(4),
        runtimeMinutes INTEGER,
        Genres VARCHAR2(500)
    )
""")

# %%
import pandas as pd

# %%
# file_path = "../datasets/title.basics.tsv"
title_basic_df = pd.read_csv("../datasets/title.basics.tsv", delimiter= '\t', index_col = 'tconst')
title_basic_df_try = title_basic_df.iloc[[0]]
# with open(file_path, 'r', encoding='utf-8') as f:
#     reader = csv.reader(f, delimiter='\t') 
#     next(reader)
#     data = [[None if col == r'\N' else col for col in row] for row in reader]
#     cur.executemany("INSERT INTO imdb_title_basics VALUES (:1, :2, :3, :4, :5, :6, :7, :8, :9)", data)

# %%
title_basic_df_try
# Out:
#       tconst titleType primaryTitle originalTitle  isAdult startYear endYear  \
# 0  tt0000001     short   Carmencita    Carmencita        0      1894      \N
#
#   runtimeMinutes             genres
# 0              1  Documentary,Short

# %%
cur.executemany("INSERT INTO imdb_title_basics VALUES (:1, :2, :3, :4, :5, :6, :7, :8, :9)", title_basic_df_try.values.tolist())



connection.commit()sss
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 cur.executemany("INSERT INTO imdb_title_basics VALUES (:1, :2, :3, :4, :5, :6, :7, :8, :9)", title_basic_df_try.values.tolist())
#       2 connection.commit()
#
# File ~/.local/lib/python3.12/site-packages/oracledb/cursor.py:924, in Cursor.executemany(self, statement, parameters, batcherrors, arraydmlrowcounts, suspend_on_success, batch_size)
#     922 self._impl.suspend_on_success = suspend_on_success
#     923 while manager.num_rows > 0:
# --> 924     self._impl.executemany(
#     925         self,
#     926         manager.num_rows,
#     927         batcherrors,
#     928         arraydmlrowcounts,
#     929         manager.message_offset,
#     930     )
#     931     manager.next_batch()
#
# File src/oracledb/impl/thin/cursor.pyx:292, in oracledb.thin_impl.ThinCursorImpl.executemany()
#
# File src/oracledb/impl/thin/cursor.pyx:182, in oracledb.thin_impl.BaseThinCursorImpl._preprocess_execute()
#
# File src/oracledb/impl/base/cursor.pyx:356, in oracledb.base_impl.BaseCursorImpl._perform_binds()
#
# File src/oracledb/impl/thin/var.pyx:105, in oracledb.thin_impl.ThinVarImpl._bind()
#
# File ~/.local/lib/python3.12/site-packages/oracledb/errors.py:199, in _raise_err(error_num, context_error_message, cause, **args)
#     194 """
#     195 Raises a driver specific exception from the specified error number and
#     196 supplied arguments.
#     197 """
#     198 error = _create_err(error_num, context_error_message, cause, **args)
# --> 199 raise error.exc_type(error) from cause
#
# DatabaseError: DPY-4009: 9 positional bind values are required but 10 were provided

# %%
cur.execute("""
    CREATE TABLE disney_plus (
        show_id VARCHAR2(20) NOT NULL PRIMARY KEY,
        Type VARCHAR2(50),
        Title VARCHAR2(500),
        Director VARCHAR2(500),
        Cast VARCHAR2(500),
        Country VARCHAR2(30),
        Date_added 
        startYear NUMBER(4),
        endYear NUMBER(4),
        runtimeMinutes INTEGER,
        Genres VARCHAR2(500)
    )
""")
